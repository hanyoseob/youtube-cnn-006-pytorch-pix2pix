# %%
# !python3 '/content/drive/My Drive/YouTube/pytorch-pix2pix/main.py' \
         --mode 'test' \
         --train_continue 'on' \
         --norm 'bnorm' \
         --opts 'direction' 0 \
         --data_dir '/content/drive/My Drive/datasets/facades' \
         --ckpt_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_a2b_bnorm' \
         --log_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/log_a2b_bnorm' \
         --result_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/result_a2b_bnorm'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 10
# number of epoch: 300
# task: pix2pix
# opts: ['direction', array([0.])]
# network: pix2pix
# learning type: plain
# data dir: /content/drive/My Drive/datasets/facades
# ckpt dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_a2b_bnorm
# log dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/log_a2b_bnorm
# result dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/result_a2b_bnorm
# device: cuda
# initialize network with normal
# initialize network with normal
# TEST: BATCH 0001 / 0011 | GEN L1 0.3294
# TEST: BATCH 0002 / 0011 | GEN L1 0.3521
# TEST: BATCH 0003 / 0011 | GEN L1 0.3504
# TEST: BATCH 0004 / 0011 | GEN L1 0.3479
# TEST: BATCH 0005 / 0011 | GEN L1 0.3475
# TEST: BATCH 0006 / 0011 | GEN L1 0.3516
# TEST: BATCH 0007 / 0011 | GEN L1 0.3535
# TEST: BATCH 0008 / 0011 | GEN L1 0.3575
# TEST: BATCH 0009 / 0011 | GEN L1 0.3582
# TEST: BATCH 0010 / 0011 | GEN L1 0.3584
# TEST: BATCH 0011 / 0011 | GEN L1 0.3563
# AVERAGE TEST: GEN L1 0.3563

# %%
# !python3 '/content/drive/My Drive/YouTube/pytorch-pix2pix/main.py' \
         --mode 'test' \
         --train_continue 'on' \
         --norm 'bnorm' \
         --opts 'direction' 1 \
         --data_dir '/content/drive/My Drive/datasets/facades' \
         --ckpt_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_b2a_bnorm' \
         --log_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/log_b2a_bnorm' \
         --result_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/result_b2a_bnorm'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 10
# number of epoch: 300
# task: pix2pix
# opts: ['direction', array([1.])]
# network: pix2pix
# learning type: plain
# data dir: /content/drive/My Drive/datasets/facades
# ckpt dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_b2a_bnorm
# log dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/log_b2a_bnorm
# result dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/result_b2a_bnorm
# device: cuda
# initialize network with normal
# initialize network with normal
# TEST: BATCH 0001 / 0011 | GEN L1 0.3269
# TEST: BATCH 0002 / 0011 | GEN L1 0.3253
# TEST: BATCH 0003 / 0011 | GEN L1 0.3296
# TEST: BATCH 0004 / 0011 | GEN L1 0.3270
# TEST: BATCH 0005 / 0011 | GEN L1 0.3181
# TEST: BATCH 0006 / 0011 | GEN L1 0.3071
# TEST: BATCH 0007 / 0011 | GEN L1 0.3035
# TEST: BATCH 0008 / 0011 | GEN L1 0.3033
# TEST: BATCH 0009 / 0011 | GEN L1 0.3107
# TEST: BATCH 0010 / 0011 | GEN L1 0.3128
# TEST: BATCH 0011 / 0011 | GEN L1 0.3078
# AVERAGE TEST: GEN L1 0.3078

# %%
# !python3 '/content/drive/My Drive/YouTube/pytorch-pix2pix/main.py' \
         --mode 'test' \
         --train_continue 'on' \
         --norm 'inorm' \
         --opts 'direction' 0 \
         --data_dir '/content/drive/My Drive/datasets/facades' \
         --ckpt_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_a2b_inorm' \
         --log_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/log_a2b_inorm' \
         --result_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/result_a2b_inorm'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 10
# number of epoch: 300
# task: pix2pix
# opts: ['direction', array([0.])]
# network: pix2pix
# learning type: plain
# data dir: /content/drive/My Drive/datasets/facades
# ckpt dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_a2b_inorm
# log dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/log_a2b_inorm
# result dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/result_a2b_inorm
# device: cuda
# initialize network with normal
# initialize network with normal
# TEST: BATCH 0001 / 0011 | GEN L1 0.3189
# TEST: BATCH 0002 / 0011 | GEN L1 0.3446
# TEST: BATCH 0003 / 0011 | GEN L1 0.3480
# TEST: BATCH 0004 / 0011 | GEN L1 0.3494
# TEST: BATCH 0005 / 0011 | GEN L1 0.3479
# TEST: BATCH 0006 / 0011 | GEN L1 0.3492
# TEST: BATCH 0007 / 0011 | GEN L1 0.3509
# TEST: BATCH 0008 / 0011 | GEN L1 0.3555
# TEST: BATCH 0009 / 0011 | GEN L1 0.3550
# TEST: BATCH 0010 / 0011 | GEN L1 0.3546
# TEST: BATCH 0011 / 0011 | GEN L1 0.3527
# AVERAGE TEST: GEN L1 0.3527

# %%
# !python3 '/content/drive/My Drive/YouTube/pytorch-pix2pix/main.py' \
         --mode 'test' \
         --train_continue 'on' \
         --norm 'inorm' \
         --opts 'direction' 1 \
         --data_dir '/content/drive/My Drive/datasets/facades' \
         --ckpt_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_b2a_inorm' \
         --log_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/log_b2a_inorm' \
         --result_dir '/content/drive/My Drive/YouTube/pytorch-pix2pix/result_b2a_inorm'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 10
# number of epoch: 300
# task: pix2pix
# opts: ['direction', array([1.])]
# network: pix2pix
# learning type: plain
# data dir: /content/drive/My Drive/datasets/facades
# ckpt dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/checkpoint_b2a_inorm
# log dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/log_b2a_inorm
# result dir: /content/drive/My Drive/YouTube/pytorch-pix2pix/result_b2a_inorm
# device: cuda
# initialize network with normal
# initialize network with normal
# TEST: BATCH 0001 / 0011 | GEN L1 0.3448
# TEST: BATCH 0002 / 0011 | GEN L1 0.3383
# TEST: BATCH 0003 / 0011 | GEN L1 0.3422
# TEST: BATCH 0004 / 0011 | GEN L1 0.3418
# TEST: BATCH 0005 / 0011 | GEN L1 0.3342
# TEST: BATCH 0006 / 0011 | GEN L1 0.3192
# TEST: BATCH 0007 / 0011 | GEN L1 0.3201
# TEST: BATCH 0008 / 0011 | GEN L1 0.3193
# TEST: BATCH 0009 / 0011 | GEN L1 0.3264
# TEST: BATCH 0010 / 0011 | GEN L1 0.3294
# TEST: BATCH 0011 / 0011 | GEN L1 0.3263
# AVERAGE TEST: GEN L1 0.3263
